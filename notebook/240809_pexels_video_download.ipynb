# %%
# %cd /home/edward/sprites
# Out:
# /home/edward/sprites

# %%
# reload source code
# %load_ext autoreload
# %autoreload 2

# %%
from pathlib import Path

# %%
from src.dogs.dogs_datafile import DogsDatafile
from src.dogs.dog_video import DogVideo
# Out:
# /home/edward/miniconda3/envs/sprites/lib/python3.10/site-packages/huggingface_hub/file_download.py:1150: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(

# %%
data_dir = Path("data")
assert data_dir.exists()
dogs_datafile = DogsDatafile(data_dir)

# %%
dogs_datafile.download_videos()

# %%
dogs_datafile.crop_dog_videos()
# Out:
#   0%|          | 0/3949 [00:00<?, ?it/s]

# %% [markdown]
# # Test cropping

# %%
from pathlib import Path

# video_path = Path("data/pexels-videos/9631902.mp4")
video_path = Path("data/pexels-videos/5593049.mp4")
assert video_path.exists()

dog_video = DogVideo(video_path)

# %%
dog_video.to_pil_frames(max_frames=16)[0]
# Out:
# <PIL.Image.Image image mode=RGB size=512x288>

# %%
dog_video.are_most_frames_the_same_dog()
# Out:
# True

# %%
dog_video.draw_dogs(10)
# Out:
# <PIL.Image.Image image mode=RGB size=512x288>

# %%
cropped_frames = dog_video.crop_video_frames(letterbox_to=(512, 512))
cropped_frames[0]
# Out:
# <PIL.Image.Image image mode=RGB size=512x512>

# %%
dog_video.crop_dog_video()
# Out:
# PosixPath('data/pexels-videos/dog-videos/5593049')
